# %% [markdown]
# # DSN AI BOOTCAMP 2026 QUALIFIER PROJECT

# %% [markdown]
# ## Problem statement
# - DSN Mart operates a chain of stores across Nigeria, from small corner shops to flagship hypermarkets, spread across major urban centres, state capitals, and smaller towns. Like any growing retail business, DSN Mart wants to understand what drives sales at the product level across its different store formats and locations, so it can plan stock, pricing, and store investment more intelligently. Build a machine learning model that predicts total sales for a given product at a given store, based on what's known about the product and the outlet it's sold in.

# %% [markdown]
# # 1. Reading train and test datasets, and also trying to get familiar with my dataset

# %%
## Import all important libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

# %%
# reading the train data using pandas module.
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head()
# Out:
#           id product_code  product_weight_kg fat_content  shelf_visibility  \
# 0  row_00000   PRD-PRFP9S             14.252     Low Fat            0.0271
# 1  row_00001   PRD-PXXK71              7.698     Low Fat            0.0720
# 2  row_00002   PRD-V5MOIJ             14.264     Regular            0.0421
# 3  row_00003   PRD-UN5Z3J                NaN     Regular            0.0449
# 4  row_00004   PRD-6RDQYB             10.338     Regular            0.0120
#
#      product_category  product_price store_code  store_age_years store_size  \
# 0        Frozen Foods          81.37  STORE-AGY               45      Large
# 1  HEALTH AND HYGIENE          42.05  STORE-YLW               35      Small
# 2              Canned          41.35  STORE-89Z               33     Medium
# 3         soft drinks         174.35  STORE-7WS               47     Medium
# 4                meat         203.06  STORE-9RG               28      Small
#
#   store_location_tier          store_format  total_sales
# 0              Tier_3  Standard Supermarket      1764.98
# 1              Tier_1  Standard Supermarket       342.13
# 2              Tier_1  Standard Supermarket       378.85
# 3              Tier_3  Flagship Hypermarket      5595.72
# 4              Tier_2  Standard Supermarket      2375.36

# %%
test_df
# Out:
#              id product_code  product_weight_kg fat_content  shelf_visibility  \
# 0     row_00009   PRD-2WLNC8              8.628     Low Fat            0.0167
# 1     row_00015   PRD-LV9PLM              6.993     Low Fat            0.0579
# 2     row_00019   PRD-ET6ZI7                NaN     Low Fat            0.1262
# 3     row_00020   PRD-6RX35U             14.034     Regular            0.0761
# 4     row_00023   PRD-I4J38V             13.063     Low Fat            0.0650
# ...         ...          ...                ...         ...               ...
# 1700  row_08483   PRD-58L9K5             17.919     Low Fat            0.0607
# 1701  row_08489   PRD-0B58ST             16.748     Regular            0.0136
# 1702  row_08491   PRD-RH8H90              9.876     Low Fat            0.0239
# 1703  row_08504   PRD-J51IFI                NaN     Low Fat            0.0221
# 1704  row_08515   PRD-6S601Z             11.284     Regular            0.1299
#
#            product_category  product_price store_code  store_age_years  \
# 0                 household         190.72  STORE-HL7               23
# 1        Health and Hygiene         261.07  STORE-9RG               28
# 2     FRUITS AND VEGETABLES         112.50  STORE-7WS               47
# 3              frozen foods         200.71  STORE-DKU               30
# 4              Frozen Foods         150.59  STORE-89Z               33
# ...                     ...            ...        ...              ...
# 1700          Starchy Foods         168.62  STORE-89Z               33
# 1701                 canned          97.26  STORE-JOR               34
# 1702     health and hygiene         183.35  STORE-HL7               23
# 1703                 Breads         166.09  STORE-7WS               47
# 1704           frozen foods         102.24  STORE-9RG               28
#
#      store_size store_location_tier          store_format
# 0        Medium              Tier_3            Superstore
# 1         Small              Tier_2  Standard Supermarket
# 2        Medium              Tier_3  Flagship Hypermarket
# 3           NaN              Tier_2  Standard Supermarket
# 4        Medium              Tier_1  Standard Supermarket
# ...         ...                 ...                   ...
# 1700     Medium              Tier_1  Standard Supermarket
# 1701        NaN              Tier_3           Corner Shop
# 1702     Medium              Tier_3            Superstore
# 1703     Medium              Tier_3  Flagship Hypermarket
# 1704      Small              Tier_2  Standard Supermarket
#
# [1705 rows x 12 columns]

# %%
train_df.describe()
# Out:
#        product_weight_kg  shelf_visibility  product_price  store_age_years  \
# count        5593.000000       6818.000000    6818.000000      6818.000000
# mean           12.850876          0.065527     140.473623        34.178205
# std             4.646542          0.051566      62.413513         8.384574
# min             4.482000          0.000000      31.110000        23.000000
# 25%             8.750000          0.026600      93.280000        28.000000
# 50%            12.647000          0.053200     142.065000        33.000000
# 75%            16.894000          0.093400     185.987500        45.000000
# max            21.883000          0.320100     273.040000        47.000000
#
#         total_sales
# count   6818.000000
# mean    2174.756574
# std     1697.894956
# min       32.700000
# 25%      834.792500
# 50%     1790.890000
# 75%     3092.587500
# max    12996.820000

# %%
test_df.describe()
# Out:
#        product_weight_kg  shelf_visibility  product_price  store_age_years
# count        1399.000000       1705.000000    1705.000000      1705.000000
# mean           12.865960          0.068491     143.069490        34.127859
# std             4.647713          0.051721      61.888692         8.322650
# min             4.693000          0.000000      31.980000        23.000000
# 25%             8.753000          0.030200      96.560000        28.000000
# 50%            12.617000          0.056400     144.630000        33.000000
# 75%            16.915500          0.098400     185.210000        45.000000
# max            21.980000          0.302000     270.870000        47.000000

# %%
train_df.shape
# Out:
# (6818, 13)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6818 entries, 0 to 6817
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6818 non-null   object
#  1   product_code         6818 non-null   object
#  2   product_weight_kg    5593 non-null   float64
#  3   fat_content          6818 non-null   object
#  4   shelf_visibility     6818 non-null   float64
#  5   product_category     6818 non-null   object
#  6   product_price        6818 non-null   float64
#  7   store_code           6818 non-null   object
#  8   store_age_years      6818 non-null   int64
#  9   store_size           4899 non-null   object
#  10  store_location_tier  6818 non-null   object
#  11  store_format         6818 non-null   object
#  12  total_sales          6818 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 692.6+ KB

# %%
train_df.isna().sum()
# Out:
# id                        0
# product_code              0
# product_weight_kg      1225
# fat_content               0
# shelf_visibility          0
# product_category          0
# product_price             0
# store_code                0
# store_age_years           0
# store_size             1919
# store_location_tier       0
# store_format              0
# total_sales               0
# dtype: int64

# %%
# Dropping the most useless columns in the dataset.
train_df.drop('id', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 2
#       1 # Dropping the most useless columns in the dataset.
# ----> 2 train_df.drop('id', axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['id'] not found in axis"

# %%
train_df
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 0      PRD-PRFP9S             14.252     Low Fat            0.0271
# 1      PRD-PXXK71              7.698     Low Fat            0.0720
# 2      PRD-V5MOIJ             14.264     Regular            0.0421
# 3      PRD-UN5Z3J                NaN     Regular            0.0449
# 4      PRD-6RDQYB             10.338     Regular            0.0120
# ...           ...                ...         ...               ...
# 6813   PRD-V56VKT              9.201     Regular            0.2851
# 6814   PRD-S1AWP0             15.770     Low Fat            0.1193
# 6815   PRD-NCP2VI             17.665     Low Fat            0.0182
# 6816   PRD-K9LSG4             20.645     Low Fat            0.0567
# 6817   PRD-ON4O79             16.703     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 0              Frozen Foods          81.37  STORE-AGY               45
# 1        HEALTH AND HYGIENE          42.05  STORE-YLW               35
# 2                    Canned          41.35  STORE-89Z               33
# 3               soft drinks         174.35  STORE-7WS               47
# 4                      meat         203.06  STORE-9RG               28
# ...                     ...            ...        ...              ...
# 6813  Fruits and Vegetables         136.57  STORE-JOR               34
# 6814           FROZEN FOODS          74.03  STORE-OYG               25
# 6815     Health and Hygiene         234.87  STORE-DKU               30
# 6816            snack foods         118.86  STORE-OYG               25
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales
# 0         Large              Tier_3  Standard Supermarket      1764.98
# 1         Small              Tier_1  Standard Supermarket       342.13
# 2        Medium              Tier_1  Standard Supermarket       378.85
# 3        Medium              Tier_3  Flagship Hypermarket      5595.72
# 4         Small              Tier_2  Standard Supermarket      2375.36
# ...         ...                 ...                   ...          ...
# 6813        NaN              Tier_3           Corner Shop       276.50
# 6814        NaN              Tier_2  Standard Supermarket      1265.63
# 6815        NaN              Tier_2  Standard Supermarket      6254.55
# 6816        NaN              Tier_2  Standard Supermarket      1658.06
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
# [6818 rows x 12 columns]

# %%
train_df.describe()
# Out:
#        product_weight_kg  shelf_visibility  product_price  store_age_years  \
# count        5593.000000       6818.000000    6818.000000      6818.000000
# mean           12.850876          0.065527     140.473623        34.178205
# std             4.646542          0.051566      62.413513         8.384574
# min             4.482000          0.000000      31.110000        23.000000
# 25%             8.750000          0.026600      93.280000        28.000000
# 50%            12.647000          0.053200     142.065000        33.000000
# 75%            16.894000          0.093400     185.987500        45.000000
# max            21.883000          0.320100     273.040000        47.000000
#
#         total_sales
# count   6818.000000
# mean    2174.756574
# std     1697.894956
# min       32.700000
# 25%      834.792500
# 50%     1790.890000
# 75%     3092.587500
# max    12996.820000

# %%
train_df['product_weight_kg'].isna().sum()
# Out:
# np.int64(1225)

# %%
train_df['product_weight_kg'].unique()
# Out:
# array([14.252,  7.698, 14.264, ..., 15.77 , 17.665, 16.703], shape=(4676,))

# %%
train_df['product_weight_kg'].mode()
# Out:
# 0    7.692
# 1    8.097
# Name: product_weight_kg, dtype: float64

# %%
train_df['product_weight_kg'].mean()
# Out:
# np.float64(12.850875916323977)

# %%
train_df['product_weight_kg'].value_counts()
# Out:
# product_weight_kg
# 8.097     5
# 7.692     5
# 17.659    4
# 9.503     4
# 11.844    4
#          ..
# 7.374     1
# 18.238    1
# 11.586    1
# 14.179    1
# 16.703    1
# Name: count, Length: 4675, dtype: int64

# %%
train_df['product_code'].unique()
# Out:
# array(['PRD-PRFP9S', 'PRD-PXXK71', 'PRD-V5MOIJ', ..., 'PRD-AF3WE8',
#        'PRD-06GUU9', 'PRD-7Q5FPH'], shape=(1555,), dtype=object)

# %%
train_df['product_code'].mode()[0]
# Out:
# 'PRD-YZB4K8'

# %%
train_df['store_code'].unique()
# Out:
# array(['STORE-AGY', 'STORE-YLW', 'STORE-89Z', 'STORE-7WS', 'STORE-9RG',
#        'STORE-HL7', 'STORE-JOR', 'STORE-T5G', 'STORE-OYG', 'STORE-DKU'],
#       dtype=object)

# %%
train_df['store_code'].value_counts()
# Out:
# store_code
# STORE-YLW    754
# STORE-9RG    752
# STORE-AGY    748
# STORE-7WS    748
# STORE-OYG    744
# STORE-HL7    742
# STORE-DKU    736
# STORE-89Z    728
# STORE-JOR    439
# STORE-T5G    427
# Name: count, dtype: int64

# %%
train_df[train_df['store_code']=='STORE-YLW']
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 1      PRD-PXXK71              7.698     Low Fat            0.0720
# 13     PRD-PGW90J             13.812     Low Fat            0.0431
# 23     PRD-2YAZQT             15.428     Regular            0.0819
# 24     PRD-Q8LYYX             11.265     Regular            0.0735
# 29     PRD-2SLHIM             20.799     Low Fat            0.0099
# ...           ...                ...         ...               ...
# 6797   PRD-R04H5W             19.232     Low Fat            0.0000
# 6806   PRD-LJKPHC             18.780     Regular            0.0958
# 6809   PRD-I67HN3             20.547     Low Fat            0.0102
# 6812   PRD-JNODL5             18.365     Low Fat            0.0154
# 6817   PRD-ON4O79             16.703     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 1        HEALTH AND HYGIENE          42.05  STORE-YLW               35
# 13                    Dairy          52.83  STORE-YLW               35
# 23             Frozen Foods          48.98  STORE-YLW               35
# 24             Frozen Foods         171.96  STORE-YLW               35
# 29                     Meat         187.29  STORE-YLW               35
# ...                     ...            ...        ...              ...
# 6797              household         190.57  STORE-YLW               35
# 6806  Fruits and Vegetables          82.59  STORE-YLW               35
# 6809              Household         233.74  STORE-YLW               35
# 6812     Health and Hygiene         161.04  STORE-YLW               35
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales
# 1         Small              Tier_1  Standard Supermarket       342.13
# 13        Small              Tier_1  Standard Supermarket       585.91
# 23        Small              Tier_1  Standard Supermarket       753.42
# 24        Small              Tier_1  Standard Supermarket      2442.31
# 29        Small              Tier_1  Standard Supermarket       536.28
# ...         ...                 ...                   ...          ...
# 6797      Small              Tier_1  Standard Supermarket       555.26
# 6806      Small              Tier_1  Standard Supermarket      1124.02
# 6809      Small              Tier_1  Standard Supermarket      3212.38
# 6812      Small              Tier_1  Standard Supermarket      1588.25
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
# [754 rows x 12 columns]

# %%
train_df.drop('id', axis=1, inplace=True)

# %%
train_df
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 0      PRD-PRFP9S             14.252     Low Fat            0.0271
# 1      PRD-PXXK71              7.698     Low Fat            0.0720
# 2      PRD-V5MOIJ             14.264     Regular            0.0421
# 3      PRD-UN5Z3J                NaN     Regular            0.0449
# 4      PRD-6RDQYB             10.338     Regular            0.0120
# ...           ...                ...         ...               ...
# 6813   PRD-V56VKT              9.201     Regular            0.2851
# 6814   PRD-S1AWP0             15.770     Low Fat            0.1193
# 6815   PRD-NCP2VI             17.665     Low Fat            0.0182
# 6816   PRD-K9LSG4             20.645     Low Fat            0.0567
# 6817   PRD-ON4O79             16.703     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 0              Frozen Foods          81.37  STORE-AGY               45
# 1        HEALTH AND HYGIENE          42.05  STORE-YLW               35
# 2                    Canned          41.35  STORE-89Z               33
# 3               soft drinks         174.35  STORE-7WS               47
# 4                      meat         203.06  STORE-9RG               28
# ...                     ...            ...        ...              ...
# 6813  Fruits and Vegetables         136.57  STORE-JOR               34
# 6814           FROZEN FOODS          74.03  STORE-OYG               25
# 6815     Health and Hygiene         234.87  STORE-DKU               30
# 6816            snack foods         118.86  STORE-OYG               25
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales
# 0         Large              Tier_3  Standard Supermarket      1764.98
# 1         Small              Tier_1  Standard Supermarket       342.13
# 2        Medium              Tier_1  Standard Supermarket       378.85
# 3        Medium              Tier_3  Flagship Hypermarket      5595.72
# 4         Small              Tier_2  Standard Supermarket      2375.36
# ...         ...                 ...                   ...          ...
# 6813        NaN              Tier_3           Corner Shop       276.50
# 6814        NaN              Tier_2  Standard Supermarket      1265.63
# 6815        NaN              Tier_2  Standard Supermarket      6254.55
# 6816        NaN              Tier_2  Standard Supermarket      1658.06
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
# [6818 rows x 12 columns]

# %% [markdown]
# # 2. Missing Values Handling/Data Cleaning

# %% [markdown]
# ## Resolving missing values in product_weight_kg
# - The same product_code appears in multiple rows meaning a product is sold at different stores, so if the weight is known for that product anywhere else, we can find the actual value instead of guessing one for it.

# %%
# I replaced all inconsistent headers in the product_category column.
train_df['product_category'] = train_df['product_category'].str.strip().str.lower()

# %%
## filling missing values in numerical variable "Product_weight_kg" with its median
train_df['product_weight_kg'] = train_df.groupby('product_code')['product_weight_kg'].transform(lambda x: x.fillna(x.median()))

# %%
train_df['product_weight_kg'] = train_df.groupby('product_category')['product_weight_kg'].transform(lambda x: x.fillna(x.median()))

# %%
train_df['product_weight_kg'].isna().sum()
# Out:
# np.int64(0)

# %%
train_df.isnull().sum()
# Out:
# product_code              0
# product_weight_kg         0
# fat_content               0
# shelf_visibility          0
# product_category          0
# product_price             0
# store_code                0
# store_age_years           0
# store_size             1919
# store_location_tier       0
# store_format              0
# total_sales               0
# dtype: int64

# %%
train_df[train_df['store_code']=='STORE-JOR']
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 9      PRD-DH2TA3              8.755     Low Fat            0.0258
# 30     PRD-NAMSQE             12.376     Regular            0.2992
# 44     PRD-4CK9XH             12.451     Low Fat            0.1737
# 78     PRD-1N8MTZ             19.413     Low Fat            0.0421
# 96     PRD-2EZP7V             12.766     Low Fat            0.0329
# ...           ...                ...         ...               ...
# 6739   PRD-UP0URE             12.199     Regular            0.1167
# 6744   PRD-VCZHN7             11.202     Low Fat            0.2755
# 6745   PRD-5WVO01              5.219     Low Fat            0.0532
# 6771   PRD-V5MOIJ             14.578     Regular            0.0669
# 6813   PRD-V56VKT              9.201     Regular            0.2851
#
#            product_category  product_price store_code  store_age_years  \
# 9                 household         104.60  STORE-JOR               34
# 30             baking goods          79.91  STORE-JOR               34
# 44                household         169.29  STORE-JOR               34
# 78                    dairy          44.58  STORE-JOR               34
# 96       health and hygiene         101.70  STORE-JOR               34
# ...                     ...            ...        ...              ...
# 6739                  dairy          47.14  STORE-JOR               34
# 6744            snack foods         126.52  STORE-JOR               34
# 6745     health and hygiene          33.64  STORE-JOR               34
# 6771                 canned          41.55  STORE-JOR               34
# 6813  fruits and vegetables         136.57  STORE-JOR               34
#
#      store_size store_location_tier store_format  total_sales
# 9         Small              Tier_3  Corner Shop       213.93
# 30        Small              Tier_3  Corner Shop       150.54
# 44        Small              Tier_3  Corner Shop       166.62
# 78        Small              Tier_3  Corner Shop        47.21
# 96        Small              Tier_3  Corner Shop       206.34
# ...         ...                 ...          ...          ...
# 6739      Small              Tier_3  Corner Shop        49.73
# 6744      Small              Tier_3  Corner Shop       377.64
# 6745      Small              Tier_3  Corner Shop        73.10
# 6771      Small              Tier_3  Corner Shop        41.63
# 6813      Small              Tier_3  Corner Shop       276.50
#
# [439 rows x 12 columns]

# %% [markdown]
# ## Resolving missing values in store_size.

# %% [markdown]
# - All missing rows come from 3 specific stores that never report store_size at all (whole store, not scattered rows) - so we can't recover it from other rows of the same store like we did for weight. Instead, store_format + store_location_tier are strongly related to store_size, so we use the most common (mode) store_size within those groups, with fallbacks in case a group combination was never observed.

# %%
train_df['store_size_was_missing'] = train_df['store_size'].isna().astype(int)

# %%
known = train_df.dropna(subset=['store_size'])

# %%
combo_mode = (known.groupby(['store_format', 'store_location_tier'])['store_size'].agg(lambda x: x.mode()[0]))

# %%
format_mode = known.groupby('store_format')['store_size'].agg(lambda x: x.mode()[0])

# %%
global_mode = known['store_size'].mode()[0]

# %%
def fill_store_size(row):
    if pd.notna(row['store_size']):
        return row['store_size']
        
    key = (row['store_format'], row['store_location_tier'])
    
    if key in combo_mode.index:
        return combo_mode[key]
    if row['store_format'] in format_mode.index:
        return format_mode[row['store_format']]
    return global_mode

# %%
train_df['store_size'] = train_df.apply(fill_store_size, axis=1)

# %%
train_df.isnull().sum()
# Out:
# product_code              0
# product_weight_kg         0
# fat_content               0
# shelf_visibility          0
# product_category          0
# product_price             0
# store_code                0
# store_age_years           0
# store_size                0
# store_location_tier       0
# store_format              0
# total_sales               0
# store_size_was_missing    0
# dtype: int64

# %%
train_df['store_size'].unique()
# Out:
# array(['Large', 'Small', 'Medium'], dtype=object)

# %%
train_df.duplicated
# Out:
# <bound method DataFrame.duplicated of      product_code  product_weight_kg fat_content  shelf_visibility  \
# 0      PRD-PRFP9S             14.252     Low Fat            0.0271
# 1      PRD-PXXK71              7.698     Low Fat            0.0720
# 2      PRD-V5MOIJ             14.264     Regular            0.0421
# 3      PRD-UN5Z3J             12.665     Regular            0.0449
# 4      PRD-6RDQYB             10.338     Regular            0.0120
# ...           ...                ...         ...               ...
# 6813   PRD-V56VKT              9.201     Regular            0.2851
# 6814   PRD-S1AWP0             15.770     Low Fat            0.1193
# 6815   PRD-NCP2VI             17.665     Low Fat            0.0182
# 6816   PRD-K9LSG4             20.645     Low Fat            0.0567
# 6817   PRD-ON4O79             16.703     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 0              frozen foods          81.37  STORE-AGY               45
# 1        health and hygiene          42.05  STORE-YLW               35
# 2                    canned          41.35  STORE-89Z               33
# 3               soft drinks         174.35  STORE-7WS               47
# 4                      meat         203.06  STORE-9RG               28
# ...                     ...            ...        ...              ...
# 6813  fruits and vegetables         136.57  STORE-JOR               34
# 6814           frozen foods          74.03  STORE-OYG               25
# 6815     health and hygiene         234.87  STORE-DKU               30
# 6816            snack foods         118.86  STORE-OYG               25
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales  \
# 0         Large              Tier_3  Standard Supermarket      1764.98
# 1         Small              Tier_1  Standard Supermarket       342.13
# 2        Medium              Tier_1  Standard Supermarket       378.85
# 3        Medium              Tier_3  Flagship Hypermarket      5595.72
# 4         Small              Tier_2  Standard Supermarket      2375.36
# ...         ...                 ...                   ...          ...
# 6813      Small              Tier_3           Corner Shop       276.50
# 6814      Small              Tier_2  Standard Supermarket      1265.63
# 6815      Small              Tier_2  Standard Supermarket      6254.55
# 6816      Small              Tier_2  Standard Supermarket      1658.06
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
#       store_size_was_missing
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 6813                       1
# 6814                       1
# 6815                       1
# 6816                       1
# 6817                       0
#
# [6818 rows x 13 columns]>

# %%
train_df
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 0      PRD-PRFP9S             14.252     Low Fat            0.0271
# 1      PRD-PXXK71              7.698     Low Fat            0.0720
# 2      PRD-V5MOIJ             14.264     Regular            0.0421
# 3      PRD-UN5Z3J             12.665     Regular            0.0449
# 4      PRD-6RDQYB             10.338     Regular            0.0120
# ...           ...                ...         ...               ...
# 6813   PRD-V56VKT              9.201     Regular            0.2851
# 6814   PRD-S1AWP0             15.770     Low Fat            0.1193
# 6815   PRD-NCP2VI             17.665     Low Fat            0.0182
# 6816   PRD-K9LSG4             20.645     Low Fat            0.0567
# 6817   PRD-ON4O79             16.703     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 0              frozen foods          81.37  STORE-AGY               45
# 1        health and hygiene          42.05  STORE-YLW               35
# 2                    canned          41.35  STORE-89Z               33
# 3               soft drinks         174.35  STORE-7WS               47
# 4                      meat         203.06  STORE-9RG               28
# ...                     ...            ...        ...              ...
# 6813  fruits and vegetables         136.57  STORE-JOR               34
# 6814           frozen foods          74.03  STORE-OYG               25
# 6815     health and hygiene         234.87  STORE-DKU               30
# 6816            snack foods         118.86  STORE-OYG               25
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales  \
# 0         Large              Tier_3  Standard Supermarket      1764.98
# 1         Small              Tier_1  Standard Supermarket       342.13
# 2        Medium              Tier_1  Standard Supermarket       378.85
# 3        Medium              Tier_3  Flagship Hypermarket      5595.72
# 4         Small              Tier_2  Standard Supermarket      2375.36
# ...         ...                 ...                   ...          ...
# 6813      Small              Tier_3           Corner Shop       276.50
# 6814      Small              Tier_2  Standard Supermarket      1265.63
# 6815      Small              Tier_2  Standard Supermarket      6254.55
# 6816      Small              Tier_2  Standard Supermarket      1658.06
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
#       store_size_was_missing
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 6813                       1
# 6814                       1
# 6815                       1
# 6816                       1
# 6817                       0
#
# [6818 rows x 13 columns]

# %%
train_df[train_df['store_size']=='Small']
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 1      PRD-PXXK71             7.6980     Low Fat            0.0720
# 4      PRD-6RDQYB            10.3380     Regular            0.0120
# 9      PRD-DH2TA3             8.7550     Low Fat            0.0258
# 10     PRD-ONGWUL            12.9695     Low Fat            0.0730
# 11     PRD-UX01UP            11.0070     Low Fat            0.0304
# ...           ...                ...         ...               ...
# 6813   PRD-V56VKT             9.2010     Regular            0.2851
# 6814   PRD-S1AWP0            15.7700     Low Fat            0.1193
# 6815   PRD-NCP2VI            17.6650     Low Fat            0.0182
# 6816   PRD-K9LSG4            20.6450     Low Fat            0.0567
# 6817   PRD-ON4O79            16.7030     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 1        health and hygiene          42.05  STORE-YLW               35
# 4                      meat         203.06  STORE-9RG               28
# 9                 household         104.60  STORE-JOR               34
# 10                household         254.12  STORE-T5G               47
# 11              snack foods         234.38  STORE-OYG               25
# ...                     ...            ...        ...              ...
# 6813  fruits and vegetables         136.57  STORE-JOR               34
# 6814           frozen foods          74.03  STORE-OYG               25
# 6815     health and hygiene         234.87  STORE-DKU               30
# 6816            snack foods         118.86  STORE-OYG               25
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales  \
# 1         Small              Tier_1  Standard Supermarket       342.13
# 4         Small              Tier_2  Standard Supermarket      2375.36
# 9         Small              Tier_3           Corner Shop       213.93
# 10        Small              Tier_1           Corner Shop       250.01
# 11        Small              Tier_2  Standard Supermarket      4414.42
# ...         ...                 ...                   ...          ...
# 6813      Small              Tier_3           Corner Shop       276.50
# 6814      Small              Tier_2  Standard Supermarket      1265.63
# 6815      Small              Tier_2  Standard Supermarket      6254.55
# 6816      Small              Tier_2  Standard Supermarket      1658.06
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
#       store_size_was_missing
# 1                          0
# 4                          0
# 9                          1
# 10                         0
# 11                         1
# ...                      ...
# 6813                       1
# 6814                       1
# 6815                       1
# 6816                       1
# 6817                       0
#
# [3852 rows x 13 columns]

# %%
# Checking the relationship between location of a store and its size.
pd.crosstab(train_df['store_location_tier'], train_df['store_size'], dropna=False)
# Out:
# store_size           Large  Medium  Small
# store_location_tier
# Tier_1                   0     728   1181
# Tier_2                   0       0   2232
# Tier_3                 748    1490    439

# %%
train_df.drop('store_size_was_missing', axis=1, inplace=True)

# %%
train_df
# Out:
#      product_code  product_weight_kg fat_content  shelf_visibility  \
# 0      PRD-PRFP9S             14.252     Low Fat            0.0271
# 1      PRD-PXXK71              7.698     Low Fat            0.0720
# 2      PRD-V5MOIJ             14.264     Regular            0.0421
# 3      PRD-UN5Z3J             12.665     Regular            0.0449
# 4      PRD-6RDQYB             10.338     Regular            0.0120
# ...           ...                ...         ...               ...
# 6813   PRD-V56VKT              9.201     Regular            0.2851
# 6814   PRD-S1AWP0             15.770     Low Fat            0.1193
# 6815   PRD-NCP2VI             17.665     Low Fat            0.0182
# 6816   PRD-K9LSG4             20.645     Low Fat            0.0567
# 6817   PRD-ON4O79             16.703     Low Fat            0.0165
#
#            product_category  product_price store_code  store_age_years  \
# 0              frozen foods          81.37  STORE-AGY               45
# 1        health and hygiene          42.05  STORE-YLW               35
# 2                    canned          41.35  STORE-89Z               33
# 3               soft drinks         174.35  STORE-7WS               47
# 4                      meat         203.06  STORE-9RG               28
# ...                     ...            ...        ...              ...
# 6813  fruits and vegetables         136.57  STORE-JOR               34
# 6814           frozen foods          74.03  STORE-OYG               25
# 6815     health and hygiene         234.87  STORE-DKU               30
# 6816            snack foods         118.86  STORE-OYG               25
# 6817              household          97.45  STORE-YLW               35
#
#      store_size store_location_tier          store_format  total_sales
# 0         Large              Tier_3  Standard Supermarket      1764.98
# 1         Small              Tier_1  Standard Supermarket       342.13
# 2        Medium              Tier_1  Standard Supermarket       378.85
# 3        Medium              Tier_3  Flagship Hypermarket      5595.72
# 4         Small              Tier_2  Standard Supermarket      2375.36
# ...         ...                 ...                   ...          ...
# 6813      Small              Tier_3           Corner Shop       276.50
# 6814      Small              Tier_2  Standard Supermarket      1265.63
# 6815      Small              Tier_2  Standard Supermarket      6254.55
# 6816      Small              Tier_2  Standard Supermarket      1658.06
# 6817      Small              Tier_1  Standard Supermarket       987.48
#
# [6818 rows x 12 columns]

# %%
train_df['product_category']
# Out:
# 0                frozen foods
# 1          health and hygiene
# 2                      canned
# 3                 soft drinks
# 4                        meat
#                 ...
# 6813    fruits and vegetables
# 6814             frozen foods
# 6815       health and hygiene
# 6816              snack foods
# 6817                household
# Name: product_category, Length: 6818, dtype: object
